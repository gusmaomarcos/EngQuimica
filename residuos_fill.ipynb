# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaomarcos/EngQuimica/blob/main/residuos_fill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
excel_file = "residuo.xlsx"
df = pd.read_excel(excel_file, index_col=0)

# %%
df.head()
# Out:
#                                  RM1     RM6+
# Massa de resíduo sólido (g)   0.8101   1.1442
# Massa de resíduo oleoso (g)  52.2292  47.2685
# Massa de PBS produzida (g)   20.0307  96.2207
# % de resíduo sólido           1.5300   2.3600
# % de resíduo oleoso          98.4700  97.6400

# %%
'''#get a color list, palette name can be changed
pal_ = list(sns.color_palette(palette='plasma_r',
                              n_colors=len(['RM1', 'RM6'])).as_hex())
#plot a pie chart
plt.figure(figsize=(14, 14))
plt.rcParams.update({'font.size': 16})
plt.pie(df['% de resíduo sólido'],
        labels= ['RM1', 'RM6'],
        colors=pal_, autopct='%1.1f%%',
        pctdistance=0.9)
plt.legend(bbox_to_anchor=(1, 1), loc=2, frameon=False)
plt.show()'''
# Out:
# "#get a color list, palette name can be changed\npal_ = list(sns.color_palette(palette='plasma_r',\n                              n_colors=len(['RM1', 'RM6'])).as_hex())\n#plot a pie chart\nplt.figure(figsize=(14, 14))\nplt.rcParams.update({'font.size': 16})\nplt.pie(df['% de resíduo sólido'],\n        labels= ['RM1', 'RM6'],\n        colors=pal_, autopct='%1.1f%%',\n        pctdistance=0.9)\nplt.legend(bbox_to_anchor=(1, 1), loc=2, frameon=False)\nplt.show()"
