# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaomarcos/EngQuimica/blob/main/patentes_pbs_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pbs = pd.read_csv('/content/drive/MyDrive/Databases/lens-export-pbs.csv')
patents = pd.read_csv('/content/drive/MyDrive/Databases/patents_over_time.csv')

# %% [markdown]
# Pesquisa por "polybutylene succinate", no The Lens, em 12/08/24.

# %%
pbs.head(3)
# Out:
#    # Jurisdiction Kind      Display Key              Lens ID Publication Date  \
# 0  1           JP    A  JP 2012153845 A  122-415-699-831-391       2012-08-16
# 1  2           JP    A  JP 2003310248 A  069-142-976-393-510       2003-11-05
# 2  3           US   B2   US 10189989 B2  136-827-188-871-673       2019-01-29
#
#    Publication Year Application Number Application Date  \
# 0              2012    JP 2011016098 A       2011-01-28
# 1              2003    JP 2002125101 A       2002-04-26
# 2              2019  US 201515300317 A       2015-03-23
#
#                  Priority Numbers  ... Sequence Count  \
# 0                 JP 2011016098 A  ...              0
# 1                 JP 2002125101 A  ...              0
# 2  EP 14163169 A;;EP 2015056096 W  ...              0
#
#                               CPC Classifications  \
# 0                                             NaN
# 1                                       Y02W30/62
# ...

# %%
patents.head(3)
# Out:
#    Document Count  Publication Year        Document Type
# 0               0              1953  Amended Application
# 1               0              1953       Amended Patent
# 2               1              1953       Granted Patent

# %%
patents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Document Count    456 non-null    int64
#  1   Publication Year  456 non-null    int64
#  2   Document Type     456 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 10.8+ KB

# %%
pbs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35111 entries, 0 to 35110
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            35111 non-null  int64
#  1   Jurisdiction                 35111 non-null  object
#  2   Kind                         35111 non-null  object
#  3   Display Key                  35111 non-null  object
#  4   Lens ID                      35111 non-null  object
#  5   Publication Date             35111 non-null  object
#  6   Publication Year             35111 non-null  int64
#  7   Application Number           35111 non-null  object
#  8   Application Date             35111 non-null  object
#  9   Priority Numbers             35055 non-null  object
#  10  Earliest Priority Date       35055 non-null  object
#  11  Title                        35111 non-null  object
#  12  Abstract                     31585 non-null  object
# ...

# %%
plt.figure(figsize=(14,5))
ax = sns.barplot(data=patents, y='Document Count', x = patents['Publication Year'], hue='Document Type')
plt.xticks(rotation=90)
plt.show()

# %%
df3_0 = patents.copy()
df3_0 = df3.query('`Document Type` == "Granted Patent"')
df3 = df3_0.query('`Publication Year` >= 1970')

plt.figure(figsize=(14,5))

ax = sns.barplot(data=df3, y=df3['Document Count'], x = df3['Publication Year'], color='black')

ax.set_xlabel('')
ax.set_ylabel('Número de Patentes Concedidas')
plt.xticks(rotation=55)

sns.despine(left = True, bottom = True)

# %% [markdown]
# Pesquisa por artigos no web of science

# %%
wos_pt1 = pd.read_excel('/content/drive/MyDrive/Databases/savedrecs_1.xls')
wos_pt2 = pd.read_excel('/content/drive/MyDrive/Databases/savedrecs_2.xls')

# %%
#wos_pt1.info()

# %%
#wos_pt2.info()

# %%
wos = pd.concat([wos_pt1, wos_pt2])
#wos.info()

# %%
wos.head()
# Out:
#   Publication Type                                            Authors  \
# 0                J                           Abbasi, RN; Rafizadeh, M
# 1                J  Xie, JY; Xu, RJ; Hwang, J; Zhu, HX; Zhang, T; ...
# 2                J                    Kumar, KS; Kaushik, D; Singh, I
# 3                J     Akindoyo, JO; Pickering, K; Beg, MD; Mucalo, M
# 4                J  Tariq, M; Schaller, M; Pérez-Camargo, RA; Petz...
#
#   Book Authors Book Editors Book Group Authors  \
# 0          NaN          NaN                NaN
# 1          NaN          NaN                NaN
# 2          NaN          NaN                NaN
# 3          NaN          NaN                NaN
# 4          NaN          NaN                NaN
#
#                                    Author Full Names Book Author Full Names  \
# 0            Abbasi, Rezvene Nayeb; Rafizadeh, Mehdi                    NaN
# 1  Xie, Jiayi; Xu, Ruijie; Hwang, Jiunnjye; Zhu, ...                    NaN
# ...

# %%
wos['Publication Year'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003,
#        2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1991])

# %%
x_axis = [1990,
 1991,
 1994,
 1995,
 1996,
 1997,
 1998,
 1999,
 2000,
 2001,
 2002,
 2003,
 2004,
 2005,
 2006,
 2007,
 2008,
 2009,
 2010,
 2011,
 2012,
 2013,
 2014,
 2015,
 2016,
 2017,
 2018,
 2019,
 2020,
 2021,
 2022,
 2023,
 2024]
x_axis
# Out:
# [1990,
#  1991,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024]

# %%
publication_counts = wos.groupby('Publication Year')['Publication Year'].count()
sns.countplot(x=publication_counts, data=wos)
# Out:
# <Axes: xlabel='Publication Year', ylabel='count'>

# %%
wos_all = pd.read_excel('/content/drive/MyDrive/Databases/savedrecs_all.xls', sheet_name='all', index_col='Ano')
wos_all
# Out:
#       Artigo
# Ano
# 2024       1
# 2024       1
# 2024       1
# 2024       1
# 2024       1
# ...      ...
# 1994       1
# 1994       1
# 1994       1
# 1994       1
# 1991       1
#
# [1702 rows x 1 columns]

# %%
plt.figure(figsize=(14,5))

ax = sns.countplot(x=wos_all.index, data=wos_all)
ax.set_xlabel('')
ax.set_ylabel('Número de Artigos Publicados', fontsize=12)

plt.xticks(rotation=55)

sns.despine(left = True, bottom = True)

plt.savefig('wos_artigos.png', dpi=600)

# %%
plt.figure(figsize=(14,5))

ax = sns.barplot(data=df3, y=df3['Document Count'], x = df3['Publication Year'], color='gray')

ax.set_xlabel('')
ax.set_ylabel('Número de Patentes Concedidas', fontsize=12)
plt.xticks(rotation=55)

sns.despine(left = True, bottom = True)
plt.savefig('patentes_lens.png', dpi=600)
