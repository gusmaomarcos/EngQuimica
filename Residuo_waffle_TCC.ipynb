# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaomarcos/EngQuimica/blob/main/Residuo_waffle_TCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install squarify

# %%
pip install font-installer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.7.4
#     Uninstalling certifi-2024.7.4:
#       Successfully uninstalled certifi-2024.7.4
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
# ...

# %%
pip install pywaffle
# Out:
# ...
#   Using cached pywaffle-1.1.1-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached fontawesomefree-6.6.0-py3-none-any.whl.metadata (853 bytes)
# ...
# Using cached pywaffle-1.1.1-py2.py3-none-any.whl (30 kB)
# Using cached fontawesomefree-6.6.0-py3-none-any.whl (25.6 MB)
# ...

# %%
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
import pandas as pd
import numpy as np
from matplotlib.lines import Line2D
#plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

import matplotlib as mpl
from matplotlib.cm import ScalarMappable
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from textwrap import wrap

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Databases/rend_rec_rm2_rm6.xlsx', sheet_name='transp')
df1.head()
# Out:
#   Amostra  Massa de PBS produzido (g)  Rendimento mássico global (%)  \
# 0     RM2                       21.96                           75.8
# 1     RM3                       19.05                           71.1
# 2     RM4                       16.25                           62.1
# 3     RM5                       19.05                           68.6
# 4     RM6                       19.90                           71.1
#
#    Recuperação volumétrica de FS (%)
# 0                               74.6
# 1                               66.7
# 2                               63.2
# 3                               66.9
# 4                               67.1

# %%
df2 = pd.read_excel('/content/drive/MyDrive/Databases/rend_rec_rm2_rm6_2.xlsx', sheet_name='transp')

# %%
#tfont = {'fontname':'Times New Roman'}
plt.title('Massa de PBS produzido (g)', size=12)

#title="Massa de PBS produzido (g)"
#plt.title(title, size=12)
colors = ['lightcoral', 'crimson', 'indianred', 'firebrick', 'darkred']
squarify.plot(sizes=df1['Massa de PBS produzido (g)'], label=df1['Massa de PBS produzido (g)'],
              pad=True, color=colors, text_kwargs={'color':'white', 'size':20})
plt.legend(df1['Amostra'], loc='lower center', bbox_to_anchor=(0.5, -0.1), ncol=5)
plt.axis('off')
plt.savefig('massa.png')
plt.show()

# %%
title="Rendimento mássico global (%)"
plt.title(title, size=12)
colors = ['lightskyblue', 'deepskyblue', 'cornflowerblue', 'mediumblue', 'navy']
squarify.plot(sizes=df1['Rendimento mássico global (%)'], label=df1['Rendimento mássico global (%)'],
              pad=True, color=colors, text_kwargs={'color':'white', 'size':20},
              )
plt.legend(df1['Amostra'], loc='lower center', bbox_to_anchor=(0.5, -0.1), ncol=5)
plt.axis('off')
plt.savefig('rendimento.png')
plt.show()

# %% [markdown]
# Gráfico Polar de Recuperação de FS

# %%
df2
# Out:
#   Amostra  Massa de PBS produzido (g)  Rendimento mássico global (%)  \
# 0     RM2                       21.96                           75.8
# 1     RM3                       19.05                           71.1
# 2     RM4                       16.25                           62.1
# 3     RM5                       19.05                           68.6
# 4     RM6                       19.90                           71.1
# 5      RM                       21.96                           75.8
#
#    Recuperação volumétrica de FS (%)
# 0                               74.6
# 1                               66.7
# 2                               63.2
# 3                               66.9
# 4                               67.1
# 5                               74.6

# %%
df1
# Out:
#   Amostra  Massa de PBS produzido (g)  Rendimento mássico global (%)  \
# 0     RM2                       21.96                           75.8
# 1     RM3                       19.05                           71.1
# 2     RM4                       16.25                           62.1
# 3     RM5                       19.05                           68.6
# 4     RM6                       19.90                           71.1
#
#    Recuperação volumétrica de FS (%)
# 0                               74.6
# 1                               66.7
# 2                               63.2
# 3                               66.9
# 4                               67.1

# %%
# Values for the x axis
ANGLES = np.linspace(0.05, 2 * np.pi - 0.05, len(df1.Amostra), endpoint=False)

# %%
ANGLES
# Out:
# array([0.05      , 1.28663706, 2.52327412, 3.75991118, 4.99654825])

# %%
VALUES = df1['Recuperação volumétrica de FS (%)'].values

# %%
VALUES
# Out:
# array([74.6, 66.7, 63.2, 66.9, 67.1])

# %%
#Mexendo com cores:
COLORS = ["#6C5B7B","#C06C84","#F67280","#F8B195"]
cmap = mpl.colors.LinearSegmentedColormap.from_list("my color", COLORS, N=256)
norm = mpl.colors.Normalize(vmin=df1['Recuperação volumétrica de FS (%)'].min(), vmax=df1['Recuperação volumétrica de FS (%)'].max())
COLORS = cmap(norm(df1['Recuperação volumétrica de FS (%)']))

# Some layout stuff ----------------------------------------------
# Initialize layout in polar coordinates
fig, ax = plt.subplots(figsize=(9, 12.6), subplot_kw={"projection": "polar"})

# Set background color to white, both axis and figure.
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

ax.set_theta_offset(1.2 * np.pi / 2)
ax.set_ylim(0, 100)

# Add geometries to the plot -------------------------------------
# See the zorder to manipulate which geometries are on top

# Add bars to represent the cumulative track lengths
ax.bar(ANGLES, VALUES, color=COLORS, alpha=0.9, width=0.52, zorder=10)

# Add dashed vertical lines. These are just references
#ax.vlines(ANGLES, 0, 3000, color='b', ls=(0, (4, 4)), zorder=11)

# Add dots to represent the mean gain
#ax.scatter(ANGLES, df1['media'], s=60, color='k', zorder=11)
y_value = 68.85
ax.plot([0, 2 * np.pi], [y_value, y_value], linestyle='--', color='k', linewidth=1.5)


# Add labels for the regions -------------------------------------
# Note the 'wrap()' function.
# The '5' means we want at most 5 consecutive letters in a word,
# but the 'break_long_words' means we don't want to break words
# longer than 5 characters.
REGION = ["\n".join(wrap(r, 5, break_long_words=False)) for r in df1.Amostra]
#REGION = df1.Amostra
REGION

# Set the labels
ax.set_xticks(ANGLES)
ax.set_xticklabels(REGION, size=12)
plt.savefig('rendimento_radial.png')

# %% [markdown]
# Waffles de recuperação de FS

# %%
df3 = pd.read_excel('/content/drive/MyDrive/Databases/rend_rec_all.xlsx', sheet_name='ALL')
df3
# Out:
#   Amostra  Recuperação volumétrica de FS (%)
# 0     RM1                                 79
# 1     RM2                                 75
# 2     RM3                                 67
# 3     RM4                                 63
# 4     RM5                                 67
# 5     RM6                                 67

# %%
from pywaffle import Waffle

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={21, 79},
    starting_location='SE',
    colors=['cornflowerblue', "darkblue"],
    title={
        'label': 'RM1',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm1_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={25, 75},
    starting_location='SE',
    colors=['bisque', "darkorange"],
    title={
        'label': 'RM2',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm2_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={33, 67},
    starting_location='SE',
    colors=['lightcoral', "firebrick"],
    title={
        'label': 'RM3',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm3_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={37, 63},
    starting_location='SE',
    colors=['lemonchiffon', "gold"],
    title={
        'label': 'RM4',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm4_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={33, 67},
    starting_location='SE',
    colors=['mediumorchid', "purple"],
    title={
        'label': 'RM5',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm5_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={33, 67},
    starting_location='SE',
    colors=['palegreen', "darkgreen"],
    title={
        'label': 'RM6',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm6_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={32, 68},
    starting_location='SE',
    colors=['silver', "k"],
    title={
        'label': 'Média',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rmmedia_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values={21, 79},
    starting_location='SE',
    colors=['wheat', "darkgoldenrod"],
    title={
        'label': 'RM1',
        'loc': 'left',
        'fontdict': {
            'fontsize': 20
        }})

plt.savefig('rm1_waffle_rec_vol_FS.png')
# Out:
# <Waffle size 640x480 with 1 Axes>
