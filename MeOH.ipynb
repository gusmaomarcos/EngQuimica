# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaomarcos/EngQuimica/blob/main/MeOH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


file_path = 'Resultados UV.xlsx'
sheet_name = 'MeOH'
df = pd.read_excel(file_path, sheet_name=sheet_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-dd4e05fd170c> in <cell line: 7>()
#       5 file_path = 'Resultados UV.xlsx'  # Update with your file path
#       6 sheet_name = 'MeOH'  # Update with your sheet name
# ----> 7 df = pd.read_excel(file_path, sheet_name=sheet_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
df.head()
# Out:
#                      Amostra Tratamento    Enzima Escala   pH  Buffer  \
# 0   PMMA Micra HCl Amilase 1     HCl 2M   Amilase  Micra  5.0     NaN
# 1   PMMA Micra HCl Amilase 2     HCl 2M   Amilase  Micra  5.0     NaN
# 2   PMMA Micra HCl Amilase 3     HCl 2M   Amilase  Micra  5.0     NaN
# 3  PMMA Micra HCl Controle 1     HCl 2M  Controle  Micra  7.0     NaN
# 4  PMMA Micra HCl Controle 2     HCl 2M  Controle  Micra  7.0     NaN
#
#    pH Buffer  diff_pH   Abs_1   Abs_2  ...  Conc_Desv_pad  \
# 0        NaN      NaN  0.1332  0.1270  ...       0.002473
# 1        NaN      NaN  0.1380  0.1268  ...       0.002024
# 2        NaN      NaN  0.1197  0.1345  ...       0.125150
# 3        NaN      NaN  0.4472  0.4673  ...       0.003867
# 4        NaN      NaN  0.4762  0.4573  ...       0.012246
#
#    Cr2O7-2 inicial (mols)  Vf (mL)  [Cr2O7-2]final (mol.L-1)  H2O final (mL)  \
# 0                0.000001        3                  0.000038               3
# ...

# %%
df.groupby('Tratamento').mean()['[CH3OH] (mol.L-1)']
# Out:
# <ipython-input-4-e956f3914541>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Tratamento').mean()['[CH3OH] (mol.L-1)']
# Tratamento
# HCl 2M     0.000359
# NaOH 2M    0.000356
# Name: [CH3OH] (mol.L-1), dtype: float64

# %%
df.groupby('Escala').mean()['[CH3OH] (mol.L-1)']
# Out:
# <ipython-input-5-6b762752717f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Escala').mean()['[CH3OH] (mol.L-1)']
# Escala
# Micra    0.000367
# Nano     0.000348
# Name: [CH3OH] (mol.L-1), dtype: float64

# %%
df.groupby('Enzima').mean()['[CH3OH] (mol.L-1)']
# Out:
# <ipython-input-6-15c61686d176>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Enzima').mean()['[CH3OH] (mol.L-1)']
# Enzima
# Amilase     0.000407
# Controle    0.000243
# Cutinase    0.000448
# Lacase      0.000314
# Lipase      0.000374
# Protease    0.000358
# Name: [CH3OH] (mol.L-1), dtype: float64
